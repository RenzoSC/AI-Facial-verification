# %% [markdown]
# ### FACIAL VERIFICATION WITH SIAMESE NETWORK
#
# This code is based on this paper https://www.cs.cmu.edu/~rsalakhu/papers/oneshot1.pdf

# %%
# %pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python matplotlib
# Out:
# Collecting tensorflow==2.4.1
#   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:04
# Collecting tensorflow-gpu==2.4.1
#   Downloading tensorflow_gpu-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.3/394.3 MB 1.3 MB/s eta 0:00:00m eta 0:00:010:00:04
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 8.5 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 1.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 284.3 kB/s eta 0:00:001m134.4 MB/s eta 0:00:01
# Collecting wheel~=0.35
#   Downloading wheel-0.42.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 909.1 kB/s eta 0:00:0031m26.6 MB/s eta 0:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 3.0 MB/s eta 0:00:000:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.0/462.0 kB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting six~=1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 469.4 kB/s eta 0:00:0031m37.7 MB/s eta 0:00:01
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 8.3 MB/s eta 0:00:000m eta 0:00:01:010:01
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 752.4 kB/s eta 0:00:0031m25.5 MB/s eta 0:00:01
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.7 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 560.3 kB/s eta 0:00:000:00:01
# Requirement already satisfied: packaging>=20.0 in /home/renzo/.pyenv/versions/3.7.17/lib/python3.7/site-packages (from matplotlib) (24.0)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 9.0 MB/s eta 0:00:000m eta 0:00:010:01:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/renzo/.pyenv/versions/3.7.17/lib/python3.7/site-packages (from matplotlib) (2.9.0.post0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 4.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.6 MB/s eta 0:00:000m eta 0:00:010:01:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 5.9 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 2.0 MB/s eta 0:00:000:00:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 2.5 MB/s eta 0:00:0031m13.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools>=41.0.0 in /home/renzo/.pyenv/versions/3.7.17/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (47.1.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.3 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.4-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 995.9 kB/s eta 0:00:000:00:01
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.6/138.6 kB 600.7 kB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 1.5 MB/s eta 0:00:00m eta 0:00:01
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 987.8 kB/s eta 0:00:0031m21.7 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.4 MB/s eta 0:00:0031m14.3 MB/s eta 0:00:01
# Installing collected packages: wrapt, typing-extensions, termcolor, tensorflow-estimator, tensorboard-plugin-wit, flatbuffers, zipp, wheel, urllib3, tensorboard-data-server, six, pyparsing, pyasn1, protobuf, pillow, oauthlib, numpy, MarkupSafe, kiwisolver, idna, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, werkzeug, rsa, requests, pyasn1-modules, opt-einsum, opencv-python, keras-preprocessing, importlib-metadata, h5py, grpcio, google-pasta, astunparse, absl-py, requests-oauthlib, matplotlib, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow-gpu, tensorflow
#   DEPRECATION: wrapt is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for wrapt ... done
#   DEPRECATION: termcolor is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for termcolor ... done
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
# Successfully installed MarkupSafe-2.1.5 absl-py-0.15.0 astunparse-1.6.3 cachetools-5.5.0 certifi-2024.12.14 charset-normalizer-3.4.1 cycler-0.11.0 flatbuffers-1.12 fonttools-4.38.0 gast-0.3.3 google-auth-2.37.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 idna-3.10 importlib-metadata-6.7.0 keras-preprocessing-1.1.2 kiwisolver-1.4.5 markdown-3.4.4 matplotlib-3.5.3 numpy-1.19.5 oauthlib-3.2.2 opencv-python-4.10.0.84 opt-einsum-3.3.0 pillow-9.5.0 protobuf-3.20.3 pyasn1-0.5.1 pyasn1-modules-0.3.0 pyparsing-3.1.4 requests-2.31.0 requests-oauthlib-2.0.0 rsa-4.9 six-1.15.0 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.4.1 tensorflow-estimator-2.4.0 tensorflow-gpu-2.4.1 termcolor-1.1.0 typing-extensions-3.7.4.3 urllib3-2.0.7 werkzeug-2.2.3 wheel-0.42.0 wrapt-1.12.1 zipp-3.15.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

#Tensorflow dependencies
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
